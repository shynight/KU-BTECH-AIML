# %% [markdown]
# <a href="https://colab.research.google.com/github/ARPIT2128/KU-BTECH-AIML/blob/main/SONIA_21BTAI15/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# program 2

# %%
cor = input().split()
x1=int(cor[0])
x2=int(cor[1])
y1=int(cor[2])
y2=int(cor[3])
a=(x2-x1)**2
b=(y2-y1)**2
dist=(a+b)**0.5
print("distance between two points is: ",round(dist,3))
# Out:
# 2 3 4 5
# distance between two points is:  1.414

# %% [markdown]
# program 1

# %%
var1 = 'this is a string'
var2 = 21
var3 = 3.0
var4 = [1,'hello',54,'23']
print(type(var1))
print(type(var2))
print(type(var3))
print(type(var4))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'list'>

# %% [markdown]
# program 3 (i) odd even

# %%
a=int(input())
if a%2==0:
  print("given number is even")
else:
  print("given number is odd")
# Out:
# 99
# given number is odd

# %% [markdown]
# program 3 (ii) armstrong number

# %%
count=0
sum=0
a=int(input())
n=a
while(n!=0):
  n//=10
  count+=1
n=a
for i in range (1,count+1):
  r=n%10
  sum+=(r**count)
  n//=10
if a==sum:
  print("armstong!")
else:
  print("not an armstrong")
# Out:
# 9474
# armstong!

# %% [markdown]
# REVERSE COUNT

# %%
i=int(input())


while i!=-1:
  print(i)
  i=i-1

# %% [markdown]
# COUNT THE NUMBER OF CHARACTERS

# %%
a="Enter a string"
b={}
for i in a:
  b[i]=a.count(i)
print(b)

# %% [markdown]
# LIST AND TUPLE

# %%
lists=["world","hello","bye"]
print(lists)

tuple=("world","hello","bye")
print(tuple)

for v in lists:
  print(v)
for v in tuple:
  print(v)
